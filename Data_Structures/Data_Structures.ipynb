# %% [markdown]
# # The Data Strucutres in Python

# %% [markdown]
# ## Variables
# > The name we typically assign to a value.

# %%
pizza_price = 8
number = 3
soda_price = 3.4

# %% [markdown]
# > Varialbels in Python are within `A-Z` or `a-z` (Python is case sensetive). After the firs letter, we can use numerics as well (e.g., a2, num1, etc.)

# %% [markdown]
# > Python is dynamic type; meaniing that we can change the value of a certain variable during the projects.

# %% [markdown]
# ### Operations

# %% [markdown]
# **Note:** The order of operations matters. `()`, `Power`, `division, & multiplication`, finally `summation and subtraction`.
# > For clarification, we use `()`.

# %%
toatl_price = (pizza_price * number) + (soda_price * number)

# %%
print (toatl_price)
# Out:
# 34.2

# %% [markdown]
# ### Signed Numbers
# > Positive numbers don't need the sign. However, for negative numbers one must add `-`.

# %%
num1 = -2
num2 = 28

# %% [markdown]
# ### Summation

# %%
num1 = 3
print (num1 + 4 )
# Out:
# 7

# %%
num1 += 1
print (num1)
# Out:
# 4

# %% [markdown]
# ### Subtraction

# %%
num3 =  25
num3 - num2
# Out:
# -3

# %% [markdown]
# ### Multiplication

# %%
num1 * 3
# Out:
# 12

# %% [markdown]
# ### Division
# > The type of the devision (/)is always float.

# %%
num2 / 7
# Out:
# 4.0

# %% [markdown]
# > To have an integer after devision, instead of `/`, one must use `//`

# %%
num2 // 7
# Out:
# 4

# %%
print (18 / 7) 
print (18 // 7)
# Out:
# 2.5714285714285716
# 2

# %% [markdown]
# >There is also another useful operator called modulo `%` to calculate the remainder of a devision.

# %%
18 % 7
# Out:
# 4

# %% [markdown]
# > The underscore `_` sign can be used for readability in large numbers.

# %% [markdown]
# ### Take to the power

# %%
2 ** 3
# Out:
# 8

# %%
num1 = 100000000
num2 = 100_000_000
num2 == num1
# Out:
# True

# %% [markdown]
# ## Quiz
# 1. what is the value of this code?
#    `x = 10,
#    y = 5,
#    z = x + y,
#    print (z)`
# 2. what is the value of this code?
#    `name = 'John',
#    age = 28,
#    print (name, age)`
# 3. Define the output of this code: print (7 * 2.0).
# 4. Define the output of this code: print (9 // 2)
# 5. In Python, which operator is used for the reminder?

# %% [markdown]
# ## Strings
# > To use string type in Python, one must use `""` or `''` and write the data between the quotes.
# > In Pyhton there is no deference between using double quotes `""` or using single quotes `''`, How ever in some cases there might be missunderstandings, to overcome such status, it is recommended to use double qoutes.

# %%
'Hello, World!'
# Out:
# 'Hello, World!'

# %%
# The missunderstanding scenario: 'The Johns's pencils is really intersting'
# Corrected version:
"The Johns's pencils is really intersting"
# Out:
# "The Johns's pencils is really intersting"

# %%
msg = "Hello, My name is Mohammad!"

# %%
print (msg)
# Out:
# Hello, My name is Mohammad!

# %%
print ('msg')
# Out:
# msg

# %% [markdown]
# ### Indexing in Stirngs

# %%
msg [0]
# Out:
# 'H'

# %%
msg [::]
# Out:
# 'Hello, My name is Mohammad!'

# %%
msg [1:5]
# Out:
# 'ello'

# %%
msg[0:5:2]
# Out:
# 'Hlo'

# %% [markdown]
# ### The most complete format of indexing:
# > message [start:end:step]

# %%
msg [::-1]
# reversing
# Out:
# '!dammahoM si eman yM ,olleH'

# %% [markdown]
# ### Length of strings

# %%
len(msg)
# Out:
# 27

# %% [markdown]
# ### Three Qoutes:

# %%
"""
Hi,
Hope you are doing great.
This is the Python Tutorial
and this is the last line
"""
# Out:
# '\nHi,\nHope you are doing great.\nThis is the Python Tutorial\nand this is the last line\n'

# %% [markdown]
# > To show enter in Python we can use `\n`

# %%
msg = "My name is Mohammad \n I am 27 years old \n and this is a test"
print (msg)
# Out:
# My name is Mohammad
#  I am 27 years old
#  and this is a test

# %% [markdown]
# **Notes:** In python, strings are **Immutable**.

# %%
name = "Mohammad"
print (name)
# Out:
# Mohammad

# %%
name [0]
name [0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 name [0]
# ----> 2 name [0]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
name
# Out:
# 'Mohammad'

# %%
name + name
# Out:
# 'MohammadMohammad'

# %%
print (name + " "+ name)
# Out:
# Mohammad Mohammad

# %%
print (name * 3)
# Out:
# MohammadMohammadMohammad

# %%
print ((name + " ") * 3)
# Out:
# Mohammad Mohammad Mohammad

# %% [markdown]
# ### Methods in Strings:
# > to fing all the methods, use: `string. + Tab`

# %%
name.count("m")
# Out:
# 2

# %%
name.find("d")
# Out:
# 7

# %%
name.find("Z")
# Out:
# -1

# %%
name.index("o")
# Out:
# 1

# %%
print (name.upper())
# Out:
# MOHAMMAD

# %%
print (name.lower())
# Out:
# mohammad

# %%
name.islower()
# Out:
# False

# %%
name2 = name.lower()
name2.islower()
# Out:
# True

# %%
msg1 = "My name is Mohammad I am 27 years old and this is a test"

# %%
msg1.split(" ")
# Out:
# ['My',
#  'name',
#  'is',
#  'Mohammad',
#  'I',
#  'am',
#  '27',
#  'years',
#  'old',
#  'and',
#  'this',
#  'is',
#  'a',
#  'test']

# %% [markdown]
# ### Data types:
# > to find the type of a variable, we can use `type(variable)`

# %%
type (name)
# Out:
# str

# %%
type("2")
# Out:
# str

# %%
type(2)
# Out:
# int

# %%
type(4/2)
# Out:
# float

# %% [markdown]
# ### String Interpolation

# %%
print ("Hello"+ " " + name)
# Out:
# Hello Mohammad

# %% [markdown]
# ### F string

# %%
age = 22
height = 184
weight = 80.298710434
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
print (f"Hello, {name}, Happy to see you. I think you are {age} years old, and {height} tall. Also, I noticed that you are {weight:1.4f} kiolograms.")
# Out:
# Hello, Mohammad, Happy to see you. I think you are 22 years old, and 184 tall. Also, I noticed that you are 80.2987 kiolograms.

# %% [markdown]
# ## Quiz
# 1. What is the ouptput of this code?
#    `text = "Python"
#    print (text[0])`
# 2. What is the ouptput of this code?
#    `text = "Python"
#    print (text[-])`
# 3. write a code to get this string: `x = "Hi, this is a string"` and do the followings:
#    * change to lower case
#    * make a list of the seperated words in this string.

# %% [markdown]
# ## Lists

# %%
my_list = [0, 1, 2, 3, 4, 5]

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %% [markdown]
# > Lsits are ordered in Python.

# %%
names = ["John", "Mike", "Sarah", "Donlad", "Joe"]

# %%
names [0]
# Out:
# 'John'

# %%
names[-1]
# Out:
# 'Joe'

# %%
names[1:3]
# Out:
# ['Mike', 'Sarah']

# %%
names[1:-1:2]
# Out:
# ['Mike', 'Donlad']

# %%
names [3:]
# Out:
# ['Donlad', 'Joe']

# %%
list2 = ["John", "Mike", "Sarah", 3.14, "Donlad", "Joe",[1,2,3]]

# %%
list2
# Out:
# ['John', 'Mike', 'Sarah', 3.14, 'Donlad', 'Joe', [1, 2, 3]]

# %%
len(list2)
# Out:
# 7

# %%
len([])
# Out:
# 0

# %% [markdown]
# > we can add lists and multiply by a value (like strings).

# %%
new = my_list + names

# %%
new * 3
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  'John',
#  'Mike',
#  'Sarah',
#  'Donlad',
#  'Joe',
#  0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  'John',
#  'Mike',
#  'Sarah',
#  'Donlad',
#  'Joe',
#  0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  'John',
#  'Mike',
#  'Sarah',
#  'Donlad',
#  'Joe']

# %% [markdown]
# ### Lsits methods:
# > similar to strings lists also provide various methods.

# %%
my_list.append(28)
my_list
# Out:
# [0, 1, 2, 3, 4, 5, 28]

# %%
my_list.pop()
# Out:
# 28

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
names
# Out:
# ['John', 'Mike', 'Sarah', 'Donlad', 'Joe']

# %%
last_name = names.pop()
last_name
# Out:
# 'Joe'

# %%
names.sort()
print(names)
# Out:
# ['Donlad', 'John', 'Mike', 'Sarah']

# %%
my_list.reverse()
print (my_list)
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
my_list.remove(5)
my_list
# Out:
# [4, 3, 2, 1, 0]

# %%
last_list = [1,2,3,4,4,5,6,7,9,9,9,7,8]
last_list
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7, 9, 9, 9, 7, 8]

# %%
last_list.sort()
last_list
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 9, 9]

# %% [markdown]
# ## Quiz
# 1. what is the output of this code?
#    `numbers = [1,2,3,4,5]
#    print(numbers[2])`
# 2. write a code such that, using lists methods, remove 3 from the list below and add 10.
#    `my_list = [1,2,3,4,5]`

# %% [markdown]
# ## Dictionaries
# > Dictionaries are a combination of key and value in `{}`

# %%
fruits_price = {'Bannana': 2, 'Apple': 5, 'Melon': 12, 'Berry': 8}

# %% [markdown]
# > We can call a key in the dictionary, with indexing:

# %%
fruits_price ['Bannana']
# Out:
# 2

# %%
grades = {
    'John': 
    {
        'Math': 3, 'Programming':3.5, 'Physics': 2.1
    },
    'Mike':
    {
        'Math': 2, 'Programming':4, 'Physics': 1.4
    },
    'Sarah':
    {
        'Math': 3.8, 'Programming':4, 'Physics': 3.9
    }
}

# %%
grades ['Sarah']
# Out:
# {'Math': 3.8, 'Programming': 4, 'Physics': 3.9}

# %%
grades ['John']['Math']
# Out:
# 3

# %% [markdown]
# ### Dictionaries Methods

# %%
grades.keys()
# Out:
# dict_keys(['John', 'Mike', 'Sarah'])

# %%
grades.values()
# Out:
# dict_values([{'Math': 3, 'Programming': 3.5, 'Physics': 2.1}, {'Math': 2, 'Programming': 4, 'Physics': 1.4}, {'Math': 3.8, 'Programming': 4, 'Physics': 3.9}])

# %% [markdown]
# > `get` function returns the values of the called key, also we can assign a vlaue (e.g., -1), such that if that key is not included in the dictionary, it returns the assigned value.

# %%
grades.get('Donald', -1)
# Out:
# -1

# %%
grades.items()
# Out:
# dict_items([('John', {'Math': 3, 'Programming': 3.5, 'Physics': 2.1}), ('Mike', {'Math': 2, 'Programming': 4, 'Physics': 1.4}), ('Sarah', {'Math': 3.8, 'Programming': 4, 'Physics': 3.9})])

# %% [markdown]
# ### Combination of methods

# %%
classes = {'A': ['John', 'Mike', 'Joe'], 'B':['Sarah', 'John','Dan']}

# %%
classes['B'][2].upper()
# Out:
# 'DAN'

# %%
classes ['A'][-1]
# Out:
# 'Joe'

# %%
last_person = classes ['B'].pop()

# %%
last_person
# Out:
# 'Dan'

# %% [markdown]
# ## Quiz
# 1. What is the output of the following code?
#    `person = {"name": "Ali", "age": 25}
#    print(person["name"])`
# 2. Write a dictionary, change the value of the second key, and print the updated dcitionary.

# %% [markdown]
# ## Tuples

# %%
t1 = (1, 2, 3, 3.14, 'Mom')

# %%
len (t1)
# Out:
# 5

# %% [markdown]
# **Note:** Tuple are **immutable**.

# %%
t1 [0] = 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 t1 [0] = 8
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Quiz
# 1. What is the output of this code?
#    `numbers = (10, 20, 30, 40)
#    print(numbers[1])`
# 2. create a tuple that provides the coordinates of point: A `(3,4)`, and calculate the distance from A to the origin `(0,0)`.
#    > Note: distance = √((x₂ - x₁)² + (y₂ - y₁)²)

# %% [markdown]
# ## Sets

# %%
my_set = set()

# %%
my_set.add(1)
my_set.add (2)

# %%
type(my_set)
# Out:
# set

# %%
chess = set()
chess.add("Mike")
chess.add("Sarah")

# %%
pot = set()
pot.add("Sarah")
pot.add("Joe")

# %%
chess.union(pot)
# Out:
# {'Joe', 'Mike', 'Sarah'}

# %%
chess.intersection(pot)
# Out:
# {'Sarah'}

# %% [markdown]
#  > Better way for adding into sets

# %%
animals = set(["Dog", "Cat", "Lion", "Tiger"])

# %%
animals
# Out:
# {'Cat', 'Dog', 'Lion', 'Tiger'}

# %% [markdown]
# ## Quiz
# 1. consider the following two sets:
#     `setA = {1, 2, 3, 4}
#      setB = {3, 4, 5, 6}`
# > write a code that calculate the union and intersection of the sets above

# %% [markdown]
# ## Bolean
# > The Boolean operation is the building block of conditions.

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
2 > 1
# Out:
# True

# %%
28 <= 54
# Out:
# True

# %%
89 >= 129
# Out:
# False

# %%
age = 28

# %%
age == 40
# Out:
# False

# %%
age != 20
# Out:
# True

# %%
(4 > 3 and 9 <= 20) or (190 < 140)
# Out:
# True

# %%
(4 > 13 or 39 <= 20) and not (190 < 140)
# Out:
# False

# %% [markdown]
# ## Quiz
# 1. Write a program that take three inputs (a, b, c) from the user and check if `a < b <= c`
# > **Note:** To get an input from the user in Python, we use `input()`, remember that the input type is always string, to change the value for arithmetic operations, we need to change it to integer by `int(input())` or float by `float(input())`.
